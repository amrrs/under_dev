# %% [markdown]
# ## Cryptocurrencies Dataset Analysis

# %% [markdown]
# ### Loading required Packages

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Read input csv data using pandas

# %%
cc = pd.read_csv('C:/Users/SA31/Documents/cryptocurrencies_prices.csv')
cc
# Out:
#       Unnamed: 0                     id                         name symbol  \
# 0              1                bitcoin                      Bitcoin    BTC
# 1              2                 ripple                       Ripple    XRP
# 2              3               ethereum                     Ethereum    ETH
# 3              4           bitcoin-cash                 Bitcoin Cash    BCH
# 4              5                cardano                      Cardano    ADA
# 5              6               litecoin                     Litecoin    LTC
# 6              7                   iota                         IOTA  MIOTA
# 7              8                    nem                          NEM    XEM
# 8              9                   dash                         Dash   DASH
# 9             10                stellar                      Stellar    XLM
# 10            11                 monero                       Monero    XMR
# 11            12                    neo                          NEO    NEO
# 12            13                    eos                          EOS    EOS
# 13            14           bitcoin-gold                 Bitcoin Gold    BTG
# 14            15                   qtum                         Qtum   QTUM
# 15            16              raiblocks                    RaiBlocks    XRB
# 16            17                   tron                         TRON    TRX
# 17            18       ethereum-classic             Ethereum Classic    ETC
# 18            19                   lisk                         Lisk    LSK
# 19            20             bitconnect                   BitConnect    BCC
# 20            21                   icon                         ICON    ICX
# 21            22              bitshares                    BitShares    BTS
# 22            23                  verge                        Verge    XVG
# 23            24                omisego                      OmiseGO    OMG
# 24            25                  zcash                        Zcash    ZEC
# 25            26                  ardor                        Ardor   ARDR
# 26            27               populous                     Populous    PPT
# 27            28                stratis                      Stratis  STRAT
# 28            29                  steem                        Steem  STEEM
# 29            30                 tether                       Tether   USDT
# ...          ...                    ...                          ...    ...
# 1351        1352              aseancoin                    Aseancoin    ASN
# 1352        1353   pabyosi-coin-special       Pabyosi Coin (Special)    PCS
# 1353        1354                  hyper                        Hyper  HYPER
# 1354        1355         gameleaguecoin               GameLeagueCoin    GML
# 1355        1356               quotient                     Quotient    XQN
# 1356        1357               voyacoin                     Voyacoin   VOYA
# 1357        1358                xaucoin                      Xaucoin    XAU
# 1358        1359              shellcoin                    ShellCoin  SHELL
# 1359        1360                dubstep                      Dubstep    DUB
# 1360        1361           cycling-coin                 Cycling Coin    CYC
# 1361        1362               opescoin                     Opescoin   OPES
# 1362        1363           bitalphacoin                 BitAlphaCoin    BAC
# 1363        1364                operand                      Operand     OP
# 1364        1365               thecreed                     TheCreed    TCR
# 1365        1366             prismchain                   PrismChain    PRM
# 1366        1367             linkedcoin                   LinkedCoin    LKC
# 1367        1368  international-diamond        International Diamond    XID
# 1368        1369             mobilecash                   MobileCash    MBL
# 1369        1370                lathaan                      LAthaan    LTH
# 1370        1371                 teamup                       TeamUp   TEAM
# 1371        1372              kashhcoin                    KashhCoin  KASHH
# 1372        1373               teracoin                     TeraCoin   TERA
# 1373        1374     internet-of-things           Internet of Things    XOT
# 1374        1375          goldunioncoin                GoldUnionCoin    GUC
# 1375        1376           aidos-kuneen                 Aidos Kuneen    ADK
# 1376        1377             casinocoin                   CasinoCoin    CSC
# 1377        1378      bitcoin-unlimited  Bitcoin Unlimited (Futures)    BTU
# 1378        1379                  qcash                        QCash     QC
# 1379        1380              farstcoin                    Farstcoin   FRCT
# 1380        1381               herocoin                     HEROcoin   PLAY
#
#       rank     price_usd     price_btc  X24h_volume_usd  market_cap_usd  \
# 0        1  13481.300000  1.000000e+00     1.425430e+10    2.261783e+11
# 1        2      2.299330  1.715700e-04     2.126830e+09    8.907408e+10
# 2        3    881.320000  6.576140e-02     4.720680e+09    8.524008e+10
# 3        4   2448.160000  1.826740e-01     1.086780e+09    4.134667e+10
# 4        5      0.705031  5.261000e-05     1.581580e+08    1.827939e+10
# 5        6    245.097000  1.828840e-02     8.463070e+08    1.337681e+10
# 6        7      4.106610  3.064200e-04     3.030400e+08    1.141445e+10
# 7        8      1.089290  8.128000e-05     6.290140e+07    9.803610e+09
# 8        9   1121.350000  8.367200e-02     1.785350e+08    8.734783e+09
# 9       10      0.483887  3.611000e-05     5.248690e+08    8.650507e+09
# 10      11    369.602000  2.757850e-02     1.692240e+08    5.746103e+09
# 11      12     87.035800  6.494340e-03     2.209140e+08    5.657327e+09
# 12      13      9.437230  7.041800e-04     4.452650e+08    5.447115e+09
# 13      14    274.597000  2.048950e-02     1.088530e+08    4.596915e+09
# 14      15     60.894300  4.543740e-03     7.044430e+08    4.492625e+09
# 15      16     32.643900  2.435790e-03     7.220980e+07    4.349744e+09
# 16      17      0.057727  4.310000e-06     6.279610e+08    3.795459e+09
# 17      18     34.874000  2.602190e-03     5.509040e+08    3.446093e+09
# 18      19     21.407600  1.597370e-03     5.372990e+07    2.495466e+09
# 19      20    387.010000  2.887750e-02     2.751640e+07    2.397095e+09
# 20      21      6.321670  4.717000e-04     1.283030e+08    2.382501e+09
# 21      22      0.881962  6.581000e-05     1.055210e+08    2.298816e+09
# 22      23      0.157105  1.172000e-05     6.259990e+08    2.265587e+09
# 23      24     19.831400  1.479760e-03     1.667430e+08    2.023647e+09
# 24      25    610.242000  4.553430e-02     2.777580e+08    1.810538e+09
# 25      26      1.658500  1.237500e-04     3.191700e+07    1.656841e+09
# 26      27     42.725900  3.188070e-03     2.382080e+06    1.581030e+09
# 27      28     15.945800  1.189830e-03     7.434110e+07    1.573603e+09
# 28      29      6.305000  4.704600e-04     8.144430e+07    1.555700e+09
# 29      30      1.004350  7.494000e-05     1.974220e+09    1.374041e+09
# ...    ...           ...           ...              ...             ...
# 1351  1352      0.002948  2.200000e-07     1.520840e+00             NaN
# 1352  1353      0.053607  4.000000e-06     1.393790e+00             NaN
# 1353  1354      0.053518  4.040000e-06              NaN             NaN
# 1354  1355      0.008633  6.000000e-07              NaN             NaN
# 1355  1356      0.006027  4.500000e-07              NaN             NaN
# 1356  1357      0.822307  6.005000e-05              NaN             NaN
# 1357  1358      0.044380  3.360000e-06              NaN             NaN
# 1358  1359      0.025921  1.970000e-06              NaN             NaN
# 1359  1360      0.002444  1.800000e-07              NaN             NaN
# 1360  1361      0.001218  9.000000e-08              NaN             NaN
# 1361  1362      0.002054  1.500000e-07              NaN             NaN
# 1362  1363      0.003830  2.800000e-07              NaN             NaN
# 1363  1364      0.001353  1.000000e-07              NaN             NaN
# 1364  1365      0.000398  3.000000e-08              NaN             NaN
# 1365  1366      0.002119  1.600000e-07              NaN             NaN
# 1366  1367      0.000411  3.000000e-08              NaN             NaN
# 1367  1368      0.004117  3.000000e-07              NaN             NaN
# 1368  1369      0.000418  3.000000e-08              NaN             NaN
# 1369  1370      0.000541  4.000000e-08              NaN             NaN
# 1370  1371      0.000411  3.000000e-08              NaN             NaN
# 1371  1372      0.000132  1.000000e-08              NaN             NaN
# 1372  1373      0.000131  1.000000e-08              NaN             NaN
# 1373  1374   1368.450000  9.999900e-02              NaN             NaN
# 1374  1375      0.027977  2.130000e-06              NaN             NaN
# 1375  1376     32.678600  1.900020e-03              NaN             NaN
# 1376  1377      0.508835  2.727000e-05              NaN             NaN
# 1377  1378     53.745700  3.970520e-03              NaN             NaN
# 1378  1379           NaN           NaN              NaN             NaN
# 1379  1380           NaN           NaN              NaN             NaN
# 1380  1381      0.020260  1.450000e-06              NaN             NaN
#
#       available_supply  total_supply    max_supply  percent_change_1h  \
# 0         1.677719e+07  1.677719e+07  2.100000e+07               0.88
# 1         3.873914e+10  9.999309e+10  1.000000e+11               1.85
# 2         9.671865e+07  9.671865e+07           NaN               0.88
# 3         1.688888e+07  1.688888e+07  2.100000e+07               0.13
# 4         2.592707e+10  3.111248e+10  4.500000e+10               0.69
# 5         5.457763e+07  5.457763e+07  8.400000e+07               1.75
# 6         2.779530e+09  2.779530e+09  2.779530e+09               4.69
# 7         9.000000e+09  9.000000e+09           NaN               1.73
# 8         7.789524e+06  7.789524e+06  1.890000e+07              -0.11
# 9         1.787712e+10  1.035705e+11           NaN               2.00
# 10        1.554673e+07  1.554673e+07           NaN              -2.57
# 11        6.500000e+07  1.000000e+08           NaN               2.43
# 12        5.771943e+08  9.000000e+08  1.000000e+09              -0.14
# 13        1.674059e+07  1.684059e+07  2.100000e+07               0.43
# 14        7.377744e+07  1.002774e+08           NaN              -0.26
# 15        1.332483e+08  1.332483e+08  1.332483e+08             -10.83
# 16        6.574819e+10  1.000000e+11           NaN              -0.16
# 17        9.881554e+07  9.881554e+07           NaN              -0.38
# 18        1.165692e+08  1.165692e+08           NaN               1.77
# 19        6.193885e+06  9.432231e+06  2.800000e+07               3.60
# 20        3.768784e+08  4.002300e+08           NaN               1.47
# 21        2.606480e+09  2.606480e+09  3.600571e+09               4.08
# 22        1.442084e+10  1.442084e+10  1.655500e+10               4.43
# 23        1.020426e+08  1.402454e+08           NaN               2.96
# 24        2.966919e+06  2.966919e+06           NaN              -1.19
# 25        9.989995e+08  9.989995e+08  9.989995e+08               0.61
# 26        3.700403e+07  5.325225e+07  5.325225e+07              -0.44
# 27        9.868447e+07  9.868447e+07           NaN               1.53
# 28        2.467408e+08  2.637149e+08           NaN               0.02
# 29        1.368090e+09  1.399999e+09           NaN               0.45
# ...                ...           ...           ...                ...
# 1351               NaN           NaN           NaN               1.26
# 1352               NaN  3.099375e+10           NaN               1.19
# 1353               NaN           NaN           NaN                NaN
# 1354               NaN           NaN           NaN                NaN
# 1355               NaN           NaN           NaN                NaN
# 1356               NaN           NaN           NaN                NaN
# 1357               NaN           NaN           NaN              -0.20
# 1358               NaN  9.491570e+07           NaN                NaN
# 1359               NaN           NaN           NaN                NaN
# 1360               NaN           NaN           NaN                NaN
# 1361               NaN           NaN           NaN                NaN
# 1362               NaN           NaN           NaN                NaN
# 1363               NaN  3.630930e+07           NaN                NaN
# 1364               NaN           NaN           NaN                NaN
# 1365               NaN           NaN           NaN                NaN
# 1366               NaN           NaN           NaN                NaN
# 1367               NaN           NaN           NaN                NaN
# 1368               NaN  1.068670e+09           NaN                NaN
# 1369               NaN           NaN           NaN                NaN
# 1370               NaN  3.010049e+08           NaN                NaN
# 1371               NaN           NaN           NaN                NaN
# 1372               NaN  9.223372e+10           NaN                NaN
# 1373               NaN  2.100000e+07  2.100000e+07                NaN
# 1374               NaN  2.100000e+08           NaN                NaN
# 1375               NaN  2.500000e+07           NaN                NaN
# 1376               NaN  3.860119e+07           NaN                NaN
# 1377               NaN           NaN           NaN                NaN
# 1378               NaN           NaN           NaN                NaN
# 1379               NaN           NaN           NaN                NaN
# 1380               NaN  2.521650e+08           NaN                NaN
#
#       percent_change_24h  percent_change_7d  last_updated
# 0                  -3.32             -10.65  1.514877e+09
# 1                   2.03             104.76  1.514877e+09
# 2                  14.21              13.91  1.514877e+09
# 3                  -2.59             -18.72  1.514877e+09
# 4                  -0.43              68.51  1.514877e+09
# 5                   5.04             -12.85  1.514877e+09
# 6                  13.19              13.13  1.514877e+09
# 7                   2.39              11.84  1.514877e+09
# 8                   6.29              -6.88  1.514877e+09
# 9                   7.18             115.87  1.514877e+09
# 10                  4.91              -0.77  1.514877e+09
# 11                 13.79              32.60  1.514877e+09
# 12                  5.37              -4.58  1.514877e+09
# 13                 -1.50             -10.42  1.514877e+09
# 14                 -1.04               4.55  1.514877e+09
# 15                 37.89             348.14  1.514877e+09
# 16                 26.92              59.12  1.514877e+09
# 17                  0.17               5.40  1.514877e+09
# 18                  4.27             -15.47  1.514877e+09
# 19                -11.24              68.30  1.514877e+09
# 20                 16.31              -0.12  1.514877e+09
# 21                 25.67              50.23  1.514877e+09
# 22                -18.63              -8.93  1.514877e+09
# 23                 -0.82              28.95  1.514877e+09
# 24                 17.58               8.27  1.514877e+09
# 25                 -1.35               0.41  1.514877e+09
# 26                  6.02               4.47  1.514877e+09
# 27                  7.49               6.89  1.514877e+09
# 28                103.36              84.92  1.514877e+09
# 29                 -0.23              -0.71  1.514877e+09
# ...                  ...                ...           ...
# 1351               -2.85             -10.46  1.514877e+09
# 1352               25.28             -28.09  1.514877e+09
# 1353               -3.95              42.76  1.514832e+09
# 1354                 NaN                NaN  1.514479e+09
# 1355               -2.88             -11.92  1.514807e+09
# 1356               -0.71             -35.32  1.514842e+09
# 1357               -4.76             -10.97  1.514874e+09
# 1358                 NaN                NaN  1.514727e+09
# 1359               -1.57              -9.27  1.514865e+09
# 1360               -1.85              14.38  1.514840e+09
# 1361               -0.71               4.58  1.514842e+09
# 1362               -0.81              -1.59  1.514844e+09
# 1363               -1.88                NaN  1.514840e+09
# 1364               -3.90                NaN  1.514830e+09
# 1365               -3.96             -11.52  1.514833e+09
# 1366               -0.55              37.44  1.514842e+09
# 1367               -0.50             -52.33  1.514853e+09
# 1368                0.99             -44.17  1.514854e+09
# 1369               -1.88              -7.40  1.514840e+09
# 1370               -0.71              -8.53  1.514842e+09
# 1371               -4.56              -5.67  1.514830e+09
# 1372                 NaN                NaN  1.514665e+09
# 1373               -0.77              -8.59  1.514845e+09
# 1374                 NaN              32.55  1.514726e+09
# 1375                 NaN                NaN  1.513174e+09
# 1376                 NaN                NaN  1.513606e+09
# 1377               -0.44             -73.94  1.514850e+09
# 1378                 NaN                NaN           NaN
# 1379                 NaN                NaN           NaN
# 1380                 NaN                NaN  1.514749e+09
#
# [1381 rows x 16 columns]

# %% [markdown]
# ### Dimension of the read dataframe

# %%
cc.shape
# Out:
# (1381, 16)

# %% [markdown]
# ### Removing row name that's present as a column

# %%
cc.drop('Unnamed: 0',1, inplace = True)

# %% [markdown]
# ### Sorting Cryptocurrencies based on their market cap

# %%
cc.sort_values('market_cap_usd', ascending = False)
cc.head(10)
# Out:
#              id          name symbol  rank     price_usd  price_btc  \
# 0       bitcoin       Bitcoin    BTC     1  13481.300000   1.000000
# 1        ripple        Ripple    XRP     2      2.299330   0.000172
# 2      ethereum      Ethereum    ETH     3    881.320000   0.065761
# 3  bitcoin-cash  Bitcoin Cash    BCH     4   2448.160000   0.182674
# 4       cardano       Cardano    ADA     5      0.705031   0.000053
# 5      litecoin      Litecoin    LTC     6    245.097000   0.018288
# 6          iota          IOTA  MIOTA     7      4.106610   0.000306
# 7           nem           NEM    XEM     8      1.089290   0.000081
# 8          dash          Dash   DASH     9   1121.350000   0.083672
# 9       stellar       Stellar    XLM    10      0.483887   0.000036
#
#    X24h_volume_usd  market_cap_usd  available_supply  total_supply  \
# 0     1.425430e+10    2.261783e+11      1.677719e+07  1.677719e+07
# 1     2.126830e+09    8.907408e+10      3.873914e+10  9.999309e+10
# 2     4.720680e+09    8.524008e+10      9.671865e+07  9.671865e+07
# 3     1.086780e+09    4.134667e+10      1.688888e+07  1.688888e+07
# 4     1.581580e+08    1.827939e+10      2.592707e+10  3.111248e+10
# 5     8.463070e+08    1.337681e+10      5.457763e+07  5.457763e+07
# 6     3.030400e+08    1.141445e+10      2.779530e+09  2.779530e+09
# 7     6.290140e+07    9.803610e+09      9.000000e+09  9.000000e+09
# 8     1.785350e+08    8.734783e+09      7.789524e+06  7.789524e+06
# 9     5.248690e+08    8.650507e+09      1.787712e+10  1.035705e+11
#
#      max_supply  percent_change_1h  percent_change_24h  percent_change_7d  \
# 0  2.100000e+07               0.88               -3.32             -10.65
# 1  1.000000e+11               1.85                2.03             104.76
# 2           NaN               0.88               14.21              13.91
# 3  2.100000e+07               0.13               -2.59             -18.72
# 4  4.500000e+10               0.69               -0.43              68.51
# 5  8.400000e+07               1.75                5.04             -12.85
# 6  2.779530e+09               4.69               13.19              13.13
# 7           NaN               1.73                2.39              11.84
# 8  1.890000e+07              -0.11                6.29              -6.88
# 9           NaN               2.00                7.18             115.87
#
#    last_updated
# 0  1.514877e+09
# 1  1.514877e+09
# 2  1.514877e+09
# 3  1.514877e+09
# 4  1.514877e+09
# 5  1.514877e+09
# 6  1.514877e+09
# 7  1.514877e+09
# 8  1.514877e+09
# 9  1.514877e+09

# %% [markdown]
# ### Distribution of Per unit usd price of Cryptocurrenices

# %%
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(10,5)
sns.violinplot(cc.dropna(subset = ['price_usd']).price_usd)

# %% [markdown]
# ### Listing of coins/tokens with more per unit price than Ethereum

# %%
more_than_ethereum = cc[['id','price_usd']][cc['price_usd'].gt(float(cc.loc[cc.id=='ethereum','price_usd']))]
# plot
#sns.set_style('ticks')
fig, ax = plt.subplots()
# the size of A4 paper
sns.set_style("whitegrid")
fig.set_size_inches(10,5)
sns.barplot('price_usd','id',data=more_than_ethereum)
hfont = {'fontname':'Helvetica','fontsize':'xx-large'}
plt.title('Currencies/tokens more than the price of Ethereum',**hfont)
# Out:
# Text(0.5,1,'Currencies/tokens more than the price of Ethereum')

# %%
# plot
#sns.set_style('ticks')
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(20.7, 10.27)

sns.set_style("whitegrid")
sns.barplot("id",'market_cap_usd',data=cc[:10], ax = ax)
hfont = {'fontname':'Helvetica','fontsize':'xx-large'}
plt.title('Top 10 Coins based on Market cap',**hfont)
# Out:
# Text(0.5,1,'Top 10 Coins based on Market cap')

# %%
# plot
#sns.set_style('ticks')
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(10, 5)

sns.set_style("whitegrid")
sns.barplot("id",'market_cap_usd',data=cc.dropna(subset = ['market_cap_usd']).sort_values('market_cap_usd', ascending = False).tail(10), ax = ax)
hfont = {'fontname':'Helvetica','fontsize':'xx-large'}
plt.title('Bottom 10 Coins based on Market cap',**hfont)
for tick in ax.get_xticklabels():
    tick.set_rotation(45)

# %%
cc.sort_values('market_cap_usd').tail(10)
# Out:
#                       id                         name symbol  rank  \
# 1371           kashhcoin                    KashhCoin  KASHH  1372
# 1372            teracoin                     TeraCoin   TERA  1373
# 1373  internet-of-things           Internet of Things    XOT  1374
# 1374       goldunioncoin                GoldUnionCoin    GUC  1375
# 1375        aidos-kuneen                 Aidos Kuneen    ADK  1376
# 1376          casinocoin                   CasinoCoin    CSC  1377
# 1377   bitcoin-unlimited  Bitcoin Unlimited (Futures)    BTU  1378
# 1378               qcash                        QCash     QC  1379
# 1379           farstcoin                    Farstcoin   FRCT  1380
# 1380            herocoin                     HEROcoin   PLAY  1381
#
#         price_usd     price_btc  X24h_volume_usd  market_cap_usd  \
# 1371     0.000132  1.000000e-08              NaN             NaN
# 1372     0.000131  1.000000e-08              NaN             NaN
# 1373  1368.450000  9.999900e-02              NaN             NaN
# 1374     0.027977  2.130000e-06              NaN             NaN
# 1375    32.678600  1.900020e-03              NaN             NaN
# 1376     0.508835  2.727000e-05              NaN             NaN
# 1377    53.745700  3.970520e-03              NaN             NaN
# 1378          NaN           NaN              NaN             NaN
# 1379          NaN           NaN              NaN             NaN
# 1380     0.020260  1.450000e-06              NaN             NaN
#
#       available_supply  total_supply  max_supply  percent_change_1h  \
# 1371               NaN           NaN         NaN                NaN
# 1372               NaN  9.223372e+10         NaN                NaN
# 1373               NaN  2.100000e+07  21000000.0                NaN
# 1374               NaN  2.100000e+08         NaN                NaN
# 1375               NaN  2.500000e+07         NaN                NaN
# 1376               NaN  3.860119e+07         NaN                NaN
# 1377               NaN           NaN         NaN                NaN
# 1378               NaN           NaN         NaN                NaN
# 1379               NaN           NaN         NaN                NaN
# 1380               NaN  2.521650e+08         NaN                NaN
#
#       percent_change_24h  percent_change_7d  last_updated
# 1371               -4.56              -5.67  1.514830e+09
# 1372                 NaN                NaN  1.514665e+09
# 1373               -0.77              -8.59  1.514845e+09
# 1374                 NaN              32.55  1.514726e+09
# 1375                 NaN                NaN  1.513174e+09
# 1376                 NaN                NaN  1.513606e+09
# 1377               -0.44             -73.94  1.514850e+09
# 1378                 NaN                NaN           NaN
# 1379                 NaN                NaN           NaN
# 1380                 NaN                NaN  1.514749e+09
